# %%
import numpy as np

def gradient_descent(x, y, lr=0.001, number_iteration=1000):
    m = x.shape[0]
    w = 0.0
    b = 0.0
    cost_history = []
    for i in range(number_iteration):
        y_pred = w * x + b
        cost = (1 / m) * np.sum((y_pred - y) ** 2)
        cost_history.append(cost)
        dw = (2 / m) * np.sum((y_pred - y) * x)
        db = (2 / m) * np.sum(y_pred - y)
        w -= lr * dw
        b -= lr * db

    return w, b, cost_history


x = np.array([1, 2, 3, 4, 5])
y = np.array([10, 40, 50, 78, 83])

w, b, cost_history = gradient_descent(x, y, lr=0.01, number_iteration=1000)
print(f"Final weight: {w:.4f}, Final bias: {b:.4f}")

# %%
import matplotlib

# %%
n_inputs = 2      
n_hidden = 2       

np.random.seed(42)
W1 = np.random.randn(n_inputs, n_hidden)   
print(W1)
# Out:
# [[ 0.49671415 -0.1382643 ]
#  [ 0.64768854  1.52302986]]
